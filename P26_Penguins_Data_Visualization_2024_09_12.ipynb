# %% [markdown]
# ## 项目：可视化帕默群岛企鹅数据

# %% [markdown]
# #### 分析目标

# %% [markdown]
# 此数据分析报告的目的是对帕默群岛上企鹅样本的相关数据进行可视化，从而探索和分析种类、性别、所在岛屿等因素，与企鹅的身体属性，包括体重、嘴峰长度和深度、鳍的长度，之间的关系。

# %% [markdown]
# #### 简介

# %% [markdown]
# 原始数据`Penguins.csv`包括334个收集自南极帕尔默群岛的3个岛屿上的企鹅样本，以及企鹅相关属性数据，包括种类名、所在岛、嘴峰长度、嘴峰深度、鳍长度、体重、性别。

# %% [markdown]
# `Penguin.csv`每列的含义如下:
# > - species: 企鹅的种类<br>
# > - island: 企鹅所在岛<br>
# > - culmen_length_mm: 企鹅嘴峰的长度 (单位为毫米)<br>
# > - culmen_depth_mm: 企鹅嘴峰的深度 (单位为毫米)<br>
# > - flipper_length_mm: 企鹅鳍的长度 (单位为毫米)<br>
# > - body_mass_g: 企鹅体重 (单位为克)<br>
# > - sex: 企鹅性别<br>

# %% [markdown]
# <img src="https://kaylafisk.com/wp-content/uploads/2022/12/963f48a6-c05e-438b-b502-255c2fda4078-1024x1024.png" alt="Penguin's Beak" width="280" height="210">

# %% [markdown]
# #### 读取数据

# %% [markdown]
# 导入数据分析所需要的库，并通过Pandas的`read.csv`函数，将原始数据文件`Penguins.csv`里的数据内容，解析为DataFrame并赋值给变量`original_data`。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Original_Data = pd.read_csv(".\\Penguins_Data\\penguins_size.csv")
Original_Data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# #### 评估和清理数据

# %% [markdown]
# 在这一部分中，我们将对在上一部分建立的`Original_Data`DataFrame所包含的数据进行评估和清理。<br>
# <br>
# 主要从两个方面进行: 结构和内容, 即整齐度和干净度。<br>
# <br>
# 数据的结构性问题指不符合"每个变量为一列，每个观察值为一行, 每个类型的观察单位为一个表格"这三个标准; 数据的内容性问题包括存在数据丢失、重复数据、无效数据等。<br>
# <br>
# 为了区分开经过清理的数据和原始的数据, 我们创建新的变量`Cleaned_Data`, 让它为`Original_Data`复制出的副本，我们之后的清理步骤都将被运用在`Cleaned_Data`上。

# %%
Cleaned_Data = Original_Data.copy()

# %% [markdown]
# #### 数据整齐度

# %%
Cleaned_Data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# 从头部的10行数据来看, 数据符合"每个变量为一列，每个观察值为一行, 每个类型的观察单位为一个表格", 因此不存在结构性问题。

# %% [markdown]
# #### 数据干净度

# %% [markdown]
# 接下来通过`info`, 对数据内容进行大致了解。

# %%
Cleaned_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# 从输出结果来看, `Cleaned_Data`数据共有344条观察值, `culmen_length_mm`、`culmen_depth_mm`、`flipper_length_mm`、`body_mass_g`变量存在缺失值, 将在后续进行评估和清理。<br>
# <br>
# 数据类型方面，我们已知`species`()、`sex`(企鹅性别)、`island`(企鹅所在岛)都是分类数据, 因此可以把数据类型转换为Category。

# %%
Cleaned_Data['species'] = Cleaned_Data['species'].astype('category') 
Cleaned_Data['sex'] = Cleaned_Data['sex'].astype('category') 
Cleaned_Data['island'] = Cleaned_Data['island'].astype('category') 
Cleaned_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    category
# dtypes: category(3), float64(4)
# memory usage: 12.3 KB

# %% [markdown]
# #### 处理缺失数据

# %% [markdown]
# 从`info`方法的输出来看, 在`Cleaned_Data`中, `culmen_length_mm`、`culmen_depth_mm`、`flipper_length_mm`、`body_mass_g`、`sex`变量存在缺失值。<br>
# <br>
# 先提取出确实这些变量的观察值进行查看。

# %%
Cleaned_Data.query('culmen_length_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
Cleaned_Data.query('culmen_depth_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
Cleaned_Data.query('flipper_length_mm.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
Cleaned_Data.query('body_mass_g.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %% [markdown]
# 以上，可以看到索引为3和339的观察值，除了种类和所属岛屿外所有变量都为空, 无法为探索企鹅身体属性相关因素提供价值，因此可以把这两行直接删除。

# %%
Cleaned_Data.drop(3, inplace= True)
Cleaned_Data.drop(339, inplace= True)

# %%
Cleaned_Data.query('sex.isna()')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
#
#      body_mass_g  sex
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN

# %% [markdown]
# 缺失性别变量的观察值具备其它数据, 仍然可以为分析提供价值, 由于Pandas以及Matplotlib、Seaborn会自动忽略缺失值, 可以保留这些行。

# %% [markdown]
# #### 处理重复数据

# %% [markdown]
# 根据数据变量的含义以及内容来看， 允许变量重复, 我们不需要对此数据检查是否存在重复值。

# %% [markdown]
# #### 处理不一致数据

# %% [markdown]
# 不一致数据可能存在于所有分类变量中，我们要查看是否存在不同值实际指代同一目标的情况。

# %%
Cleaned_Data['species'].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
Cleaned_Data['island'].value_counts()
# Out:
# island
# Biscoe       167
# Dream        124
# Torgersen     51
# Name: count, dtype: int64

# %%
Cleaned_Data['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %% [markdown]
# 从以上输出来看, `species`和`island`列里并不存在不一致数据, 但`sex`里存在一个英文句号值, 并不代表任何有效性别, 我们应当把该值替换为`NAN`空值。

# %%
# Cleaned_Data['sex'] = Cleaned_Data['sex'].replace(".", np.nan)
Cleaned_Data['sex'] = Cleaned_Data['sex'].cat.rename_categories(lambda x: np.nan if x == "." else x)

# %% [markdown]
# 看看英文句号值是否存在。

# %%
Cleaned_Data["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %% [markdown]
# 英文句号值已被替换为空值, 因此`sex`列里不存在不一致数据。

# %% [markdown]
# #### 处理无效或错误数据

# %% [markdown]
# 可以通过DataFrame的`describe`方法, 对数值统计信息进行快速了解。

# %%
Cleaned_Data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# 从以上统计信息来看, `cleaned_house_price`不存在脱离现实意义的数值。

# %%
# 设置图表色盘为"pastel"
sns.set_palette("pastel")

# %%
Cleaned_Data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# #### 企鹅种类比例

# %%
# Cleaned_Data.groupby("species")["island"].count()

# %%
Species_Count = Cleaned_Data["species"].value_counts()
Species_Count
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
plt.pie(Species_Count, autopct = '%.0f%%', labels = Species_Count.index)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 样本中`Adelie`这个种类的企鹅占比最大, `Gentoo`种类的占比次之, `Chinstrap`的占比最小, 为1/5左右。

# %% [markdown]
# #### 企鹅所属岛屿比例

# %%
Island_Count = Cleaned_Data["island"].value_counts()
Island_Count
# Out:
# island
# Biscoe       167
# Dream        124
# Torgersen     51
# Name: count, dtype: int64

# %%
plt.pie(Island_Count, autopct = '%.0f%%', labels = Island_Count.index)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 样本中一半左右的企鹅样本都来自`Biscoe`岛屿, 占比最大, 其次是`Dream`岛屿, `Torgersen`岛屿的样本最少。

# %% [markdown]
# #### 企鹅性别比例

# %%
Sex_Count = Cleaned_Data["sex"].value_counts()
Sex_Count
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
plt.pie(Sex_Count, autopct = '%.0f%%', labels = Sex_Count.index)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 样本企鹅的性别占比持平, 符合随机抽样。

# %% [markdown]
# #### 不同岛上的企鹅种类数量

# %%
sns.countplot(Cleaned_Data, x = "island", hue = "species")
plt.show()

# %% [markdown]
# 从以上可以看出, `Adelie`种类的企鹅样本在`Biscoe`、`Dream`、`Torgersen`这三个岛上都有, 而`Chinstrap`种类只在`Dream`岛上才有, `Gentoo`只在`Biscoe`岛上才有。

# %% [markdown]
# #### 不同岛上的企鹅性别数量

# %%
sns.countplot(Cleaned_Data, x = "island", hue = "sex")
plt.show()

# %% [markdown]
# #### 查看数值之间的相关关系

# %%
sns.pairplot(Cleaned_Data)
plt.show()

# %% [markdown]
# 从直方图来看, 企鹅样本的嘴峰长度, 嘴峰深度, 鳍长度, 体重的分布不是正态分布, 一方面说明, 这里面可能包含了多组存在差异的样本数据, 另一方面也说明样本数量不够大。<br>
# <br>
# 另外可以在散点图中看出明显的多个集群, 肯能与某些因素有关, 比如企鹅种类、性别, 因此可以对对比进行进一步的分类。

# %% [markdown]
# #### 根据种类查看数值之间的相关关系

# %%
sns.pairplot(Cleaned_Data, hue = "species")
plt.show()

# %% [markdown]
# 同一种类型的企鹅样本数据, 在散点图上基本都聚在一起, 说明同一种类型的企鹅在嘴峰长度、嘴峰深度、鳍长度、体重之间关系上, 存在相似性, 这些发现有利于我们根据体重、鳍长等数值推测企鹅种类, 也可以根据企鹅种类推测体重、鳍长等数值。

# %%
sns.pairplot(Cleaned_Data, hue = "species", kind = "reg")
plt.show()

# %%
sns.pairplot(Cleaned_Data, hue = "species", kind = "reg", plot_kws = {"scatter_kws": {'alpha': 0.3}})
plt.show()

# %% [markdown]
# 散点图结合线性回归线来看, 同类企鹅的属性数据之间均呈线性正比, 即嘴峰越长, 嘴峰越深, 鳍越长, 体重越重, 嘴峰越短, 嘴峰越浅, 鳍越短, 体重越轻。

# %%
sns.scatterplot(Cleaned_Data, x= "body_mass_g", y= "flipper_length_mm", alpha = 0.3)
# sns.pairplot(Cleaned_Data, vars=["body_mass_g", "flipper_length_mm"], kind="scatter", plot_kws={'alpha':0.3})
plt.show()

# %% [markdown]
# 从密度图的分布来看, 可以得到以下关于样本的发现:
# - Chinstrap和Gentoo的嘴峰长度范围较为接近, 而Adelle的嘴峰长度更短。<br>
# - Adelle和Chinstrap的嘴峰深度较为接近, 而Gentoo的嘴峰深度更短。<br>
# - Adelle的鳍长最短，Chinstrap中等, 而Gentoo的鳍长度最长。<br>
# - Adelle和Chinstrap的体重范围较为接近, 而Gentoo的体重更大。

# %% [markdown]
# 但不同种类的属性数值是否存在统计显著性差异, 仍然需要进行假设检验后才能得到结论。

# %% [markdown]
# #### 根据性别查看数值之间的相关关系

# %%
sns.pairplot(Cleaned_Data, hue = "sex")
plt.show()

# %% [markdown]
# 根据性别划分后可以看出, 样本中雄性企鹅各项属性数值方面大于雌性企鹅。

# %%
git lfs install
# Out:
#   Cell In[1], line 1
#     git lfs install
#         ^
# SyntaxError: invalid syntax
